% %% [markdown]
% # Introduccion a Octave
%
% Octave es un software libre para el calculo numérico, es un clon de Matlab y compatible casi al 100% con él. Veremos como utilizar Octave para realizar cálculos sencillos y gráficas
%
% ## Entorno grafico
%
% ![octave.png](attachment:octave.png)
%
% Identifiquemos
%
%     El area de edicion
%     La linea de comandos
%     El historial
%     Las variables
%     Los archivos
%
% ## Primer Ejemplo
%
% Graficar la trayectoria de un proyectil si su posicion $(x,y)$ esta dada por
%
% $$y=v_0t-0.5gt^2$$

% %%
% Programa para calcular la trayectoria
% de un proyectil

v0 = 5; % magnitud de la velocidad inicial
theta0 = 45; % angulo de disparo
g = 9.81; % gravedad
t = linspace(0,1,1000); % vector de tiempo
x = v0*cos(theta0)*t; % posicion horizontal
y = v0*sin(theta0)*t - 0.5*g*t.^2; % posicion vertical
plot(x,y);
xlabel('x (m)'); % rotulo del eje X
ylabel('y (m)'); % rotulo del eje Y
title('y vs x'); % titulo del grafico 
#saveas(gcf,'figura01.png'); # se usa para guardar el grafico
